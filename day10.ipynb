# %% [markdown]
# **Pandas**

# %%
import pandas as pd
df=pd.DataFrame([10,20,30],columns=["age"])
df1=pd.Series([10,20,30])
print(df)
print("---------")
print(df1)
# Out:
#    age
# 0   10
# 1   20
# 2   30
# ---------
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import pandas as pd
dict={"name":["dheeraj","kunal","praveen","anjali","abhishek"],"age":[20,21,22,23,24],"salary":[{"In-hand":"15000","ctc":"1.2lpa"},{"In-hand":"20000","ctc":"2.2lpa"},{"In-hand":"25000","ctc":"3.2lpa"},{"In-hand":"25000","ctc":"3.2lpa"},{"In-hand":"30000","ctc":"3.4lpa"}]}

print(pd.DataFrame(dict))
print("_---------")
print(pd.Series(dict))
# Out:
#        name  age                                 salary
# 0   dheeraj   20  {'In-hand': '15000', 'ctc': '1.2lpa'}
# 1     kunal   21  {'In-hand': '20000', 'ctc': '2.2lpa'}
# 2   praveen   22  {'In-hand': '25000', 'ctc': '3.2lpa'}
# 3    anjali   23  {'In-hand': '25000', 'ctc': '3.2lpa'}
# 4  abhishek   24  {'In-hand': '30000', 'ctc': '3.4lpa'}
# _---------
# name            [dheeraj, kunal, praveen, anjali, abhishek]
# age                                    [20, 21, 22, 23, 24]
# salary    [{'In-hand': '15000', 'ctc': '1.2lpa'}, {'In-h...
# dtype: object

# %% [markdown]
# *   CSV=".csv"
#
# *   Excel=".xlsx"
#
# *   JSon=".json"

# %%
#csv(using Github)
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/Book1.csv"
# from google.colab import drive
# # drive.mount('/content/drive')
# url = "/content/drive/MyDrive/Book1.csv"
# df=pd.read_csv(url)
# print(df)



# csv to json

url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/Book1.csv"
df=pd.read_csv(url)
df.to_json(file1.json)

# csv to Excel

df.to_excel(file2.xlsx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1323/3096681335.py in <cell line: 0>()
#      14 url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/Book1.csv"
#      15 df=pd.read_csv(url)
# ---> 16 df.to_json(file1.json)
#      17
#      18 # csv to Excel
#
# NameError: name 'file1' is not defined
