# %%
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
print(df)
#head -> starting (n) rows ka data

print(df.head(2))
print("------------Negative number-------------")
# for negative number
print(df.head(-2)) #print index other from -1 to number pass in head
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#       name  roll no  marks
# 0  dheeraj      123     10
# 1    kunal     1234     20
# ------------Negative number-------------
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30

# %%
#Tail
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
print(df.tail(2))

print("-------------negative--------------")
print(df.tail(-2))
#Shape
print(df.shape)
# Out:
#       name  roll no  marks
# 3  praveen    12356     40
# 4   anjali  1234567     50
# -------------negative--------------
#        name  roll no  marks
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
# (5, 3)

# %%
#info()
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
print(df.info(verbose=False))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Columns: 3 entries, name to marks
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None

# %%
#Rename
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
df.rename(columns={"name":"student_name"},inplace=True)
print(df)

print(df.describe())
# Out:
#   student_name  roll no  marks
# 0      dheeraj      123     10
# 1        kunal     1234     20
# 2     abhishek    12345     30
# 3      praveen    12356     40
# 4       anjali  1234567     50
#             roll no      marks
# count  5.000000e+00   5.000000
# mean   2.521250e+05  30.000000
# std    5.492329e+05  15.811388
# min    1.230000e+02  10.000000
# 25%    1.234000e+03  20.000000
# 50%    1.234500e+04  30.000000
# 75%    1.235600e+04  40.000000
# max    1.234567e+06  50.000000

# %%
import pandas as pd

data = {
    "Emp_ID": [101, 102, 103, 104, 105, 106],
    "Name": ["Amit", "Riya", "Raj", "Sara", "John", "Neha"],
    "Department": ["IT", "HR", "Finance", "IT", "Sales", "HR"],
    "Salary": [50000, 45000, 60000, 55000, 48000, 52000],
    "Experience": [2, 3, 5, 4, 1, 3]
}

print("--------------------------------Data-------------------------")
df = pd.DataFrame(data)
print(df)
print("-----------------------------Head-----------------------------")
print(df.head(3))
print("--------------------------------Tail-------------------------")
print(df.tail(-1))
print("--------------------------------Rename-------------------------")
print(df.rename(columns={"Department":"Sector"}))
print("--------------------------------Shape-------------------------")
print(df.shape)
print("--------------------------------Info-------------------------")
print(df.info())
print("--------------------------------Describe-------------------------")
print(df.describe())
print("-----------------------")
# Out:
# --------------------------------Data-------------------------
#    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
# 3     104  Sara         IT   55000           4
# 4     105  John      Sales   48000           1
# 5     106  Neha         HR   52000           3
# -----------------------------Head-----------------------------
#    Emp_ID  Name Department  Salary  Experience
# 0     101  Amit         IT   50000           2
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
# --------------------------------Tail-------------------------
#    Emp_ID  Name Department  Salary  Experience
# 1     102  Riya         HR   45000           3
# 2     103   Raj    Finance   60000           5
# 3     104  Sara         IT   55000           4
# 4     105  John      Sales   48000           1
# ...

# %%
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
print(df)
#get Single column data
df["name"]
#Add new Column
df["Salary"]=df["marks"]*100
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
#        name  roll no  marks  Salary
# 0   dheeraj      123     10    1000
# 1     kunal     1234     20    2000
# 2  abhishek    12345     30    3000
# 3   praveen    12356     40    4000
# 4    anjali  1234567     50    5000

# %%
import pandas as pd
d={"name":["vishal",'Virat',"Dheeraj"],
   "Salary":[100,200,300]
   }
df=pd.DataFrame(data=d)
   #add column
df["marks"]=df["Salary"]/10
df["Increment(10%)"]=df["Salary"]+df["Salary"]/10
print(df)
print("--------------Change column name ----------")
#change column name
df.rename(columns={"Increment(10%)":"Salary Increment(10%)"},inplace=True)
print(df)
# Out:
#       name  Salary  marks  Increment(10%)
# 0   vishal     100   10.0           110.0
# 1    Virat     200   20.0           220.0
# 2  Dheeraj     300   30.0           330.0
# --------------Change column name ----------
#       name  Salary  marks  Salary Increment(10%)
# 0   vishal     100   10.0                  110.0
# 1    Virat     200   20.0                  220.0
# 2  Dheeraj     300   30.0                  330.0
