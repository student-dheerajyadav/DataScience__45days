# %%
print("hello")
# Out:
# hello

# %%
print("second hello")
# Out:
# second hello

# %%
# conditional statement
age =18
if age>=18 :
  print("valid voter")
else:
  print("not a valid voter")
# if else
num=int(input("enter the number"))
if num :
  print(num)
else:
    print("zero:",num)
# else-if
age=int(input("enter the number"))
if age==18 :
  print("your age is",age)
elif age>18 :
  print("your age is above then 18:",age)
else :
  print("you are less then 18:",age)
# Out:
# enter your marks78
# b

# %%
# student grade
marks=int(input("enter your marks"))
if marks>60 and marks<75 :
  print("c")
elif marks>=75 and marks<=90:
  print("b")
elif marks>=90 :
  print("A")
else :
  print("fail")
# Out:
# enter your marks85
# b

# %% [markdown]
# loops
# **1. for**
# **2. while**

# %%
# #for loop
# # for i in range(1,6):
# #   print("i = ",i )
# l=[1,27,3,4,5]
# for i in l:
#   print(i)
# print("length :",len(l))
# while loop
# num1=int(input("enter your number:"))
# i=1
# while i<=num1 :
#   print(i)
#   i=i+1
# list
i=0
l=[11,12,13,14,154,36]
while i<len(l) :
  print(l[i])
  i+=1
# Out:
# 11
# 12
# 13
# 14
# 154
# 36

# %%
# example for loops  using while loop
# d={"name" :"dheeraj","age":18, "No. ":"8398986262"}
# l=d.keys()
# print(l)
# while
l=[10,[11,12,13,14]]

for i in (l[1]):
  print(i)
  i+=1
for i in range(len(l[1])):
  print(l[1][i])
# Out:
# 11
# 12
# 13
# 14
# 11
# 12
# 13
# 14
