# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/moviesTMBD.csv"
df=pd.read_csv(url)
#data cleaning
# df.drop(["id","title","adult","original_language","overview","release_date"],axis=1,inplace=True)
df

# split data
x=df[["vote_average","vote_count"]]
y=df["popularity"]

# trian test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

#feature scalling
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)


#model train
model=LinearRegression()
model.fit(x_train,y_train)


v_avg=float(input("enter vote_average"))
v_count=int(input("enter vote count"))
new_data = pd.DataFrame({
    "vote_average":[v_avg],
    "vote_count":[v_count]
})

# new_data[["vote_average","vote_count"]] = scaler.transform(
#     new_data[["vote_average","vote_count"]]
# )
new_data = scaler.transform(new_data)

#  #predict
predict_Data=model.predict(new_data)
print("popularity : ",predict_Data[0])
# Out:
# enter vote_average8.987
# enter vote count1320
# popularity :  6.937336489282186
