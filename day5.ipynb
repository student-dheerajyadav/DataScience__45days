# %% [markdown]
# **OOPS CONCEPT IN PYTHON**

# %%
#example 1.
class dheeraj:
  def __init__(self,name):
    self.name=name
  def show(self):
    print(self.name)
r=dheeraj("hello World")
r.show()


#exapmle 2.
class dheeraj:
  def __init__(self):
    print("calling conutructor")
  def show(self):
    print("Show the name")
d=dheeraj()
d.show()


#example 3.
class dheeraj:
  def __init__(self,name,age):
    self.name=name
    self.age=age
    print(type(self))
  def getAge(self):
    print("My age is :",self.age)
  def getName(self):
    print("My Name is :",self.name)
d=dheeraj("dheeraj",20)


#example 4.
class student:
  def __init__(self,*args):
    print(type(args))
    self.name=args[0]
  def getstd(self):
    # print("the student name is :",self.name)
    return self.name

s=student("hello","987089975",20,"yadavdheeraj272@gmail.com")
t=s.getstd()
print(t)

#Example 5.
class classroom:
  def __init__(self ,args):
    print(type(args))
    print(args)
    self.name=args
  def getData(self):
    return self.name
c=classroom({"name":"dheeraj","age":18})
print(c.getData()["name"])
print(c.getData()["age"])



#Example
class student:
  def __init__(self,*args):
    self.data=args

  def users(self):
    for i in self.data[0]:
      print(i)


  def details(self):
    for i in self.data[1]:
      print(i,"=",self.data[1][i])

s= student(["dheeraj","kunal","harsh","praven"],{"address":"kukas","college":"arya","loc":"jaipur"})
s.users()
s.details()
# Out:
# hello World
# calling conutructor
# Show the name
# <class '__main__.dheeraj'>
# <class 'tuple'>
# hello
# <class 'dict'>
# {'name': 'dheeraj', 'age': 18}
# dheeraj
# 18
# dheeraj
# kunal
# harsh
# praven
# address = kukas
# college = arya
# loc = jaipur
