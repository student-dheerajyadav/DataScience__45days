# %% [markdown]
# **NLP**

# %%
# nlp -> natural language processing
# nlp -> nlp is a branch of A.I and Deep learning  that enables the computer to understand,read,write, and generate human language
# !pip install nltk

from nltk.tokenize import word_tokenize
str="i love Machine learning"
token=word_tokenize()

# %%
import nltk
from nltk.tokenize import word_tokenize
# nltk.download('punkt_tab')

str = "I love Machine Learning"
str1=" my name is dheeraj yadav "
tokens = word_tokenize(str)
tokens2 = word_tokenize(str1)

print(tokens)
print(tokens2)
# Out:
# ['I', 'love', 'Machine', 'Learning']
# ['my', 'name', 'is', 'dheeraj', 'yadav']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
# nltk.download('stopwords')
str2="The machine learning is a interesting topic "
words=word_tokenize(str2)
print("words :",words)
stop_words=set(stopwords.words("english"))
print("stop_words :",stop_words)


#filter data
filtered=[]
for word in words:
  if word.lower() not in stop_words:
    filtered.append(word)


#print filter data

print("filter data :",filtered)
# Out:
# words : ['The', 'machine', 'learning', 'is', 'a', 'interesting', 'topic']
# ...

# %%
# stemming -> converts words into their root form

from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
print(stemmer.stem("playing"))
print(stemmer.stem("played"))
print(stemmer.stem("playe"))
# Out:
# play
# play
# play

# %%
#create a project with combinatin of tokenization,removal of stopWord and port stemming
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

str=" hii my name is dheeraj yadav a student of Arya college of engineering usually going to college by driving scooty"
words=word_tokenize(str)
stop_words=set(stopwords.words("english"))
# print(stop_words)

# filter words
filtered=[]
for word in words:
  if word.lower() not in stop_words:
    filtered.append(stemmer.stem(word))



print(filtered)
# Out:
# ['hii', 'name', 'dheeraj', 'yadav', 'student', 'arya', 'colleg', 'engin', 'usual', 'go', 'colleg', 'drive', 'scooti']
