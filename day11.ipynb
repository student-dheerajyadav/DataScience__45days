# %%
import pandas as pd
d={"name":"Dheeraj","age":18,"roll":11}
df=pd.Series(data=d)
print(type(df))
print(df)
# Out:
# <class 'pandas.core.series.Series'>
# name    Dheeraj
# age          18
# roll         11
# dtype: object

# %%
#DataFrames
import pandas as pd
dict={
    "name":["Dheeraj","Kunal","Anjali","Anushka","Yash"]
    ,"Age":[12,13,14,15,16]
}
df=pd.DataFrame(data=dict)
print(df)
print(type(df))
# Out:
#       name  Age
# 0  Dheeraj   12
# 1    Kunal   13
# 2   Anjali   14
# 3  Anushka   15
# 4     Yash   16
# <class 'pandas.core.frame.DataFrame'>

# %%
#csv
import pandas as pd

url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/Book1.csv"

df=pd.read_csv(url)
print(df)
# Out:
#       name  roll.
# 0  Dheeraj     11
# 1    kunal     18
# 2  anushka      8
# 3   nikita     25
# 4     yash     35
