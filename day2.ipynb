# %% [markdown]
# **functions in python**

# %%
#function
def hello():
  print("hello function is calling")
hello()




#eample 2.
def hello1():
   print("a")
hello1()




#Example 3.
def hello3(a,b):
  print(a+b)
hello3(2,3)



#example 4.
def power(a,b):
  print(a**b)
power(2,5)
power(b=5,a=3)



#exapmle 5.
def student(*a):

  print(a)
  print(type(a))
student(1,2,3,4,5,6)


#question
def marks(l):
  i=0
  while i<len(l):
    print(l[i])
    i+=1

marks([10,20,30,40,50])
#question
def address(l):

  for i in l[0]:
    print(i)

address(["hello","yourname"])


# question
def sum(a,b):
  return a+b
cal=sum(2,3)
print("sum = ",cal)
# Out:
# hello function is calling
# a
# 5
# 32
# 243
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>
# 10
# 20
# 30
# 40
# 50
# h
# e
# l
# l
# o
# sum =  5
# jaipur
# kukas
# home town
# friend house

# %%
# lamda fuction  [lamda argument : expression]
add=lambda x,y,z:x+y*z
print(add(100,200,2))



add=lambda *b:b[0]+b[1]
print(add(11,23))
# Out:
# 500
# 34

# %%
#list compherension
l=[10,20,30,40,50]
print([l[i] for i in range(len(l))])


#question
l=[10,20,[30,40,50,60]]
print([l[2][i] for i in range(len(l[2]))])
# Out:
# [10, 20, 30, 40, 50]
# [30, 40, 50, 60]

# %%
#list

l=[10,20,30,40,"hello",True]
print("length of list is : ",len(l))


print(l)
print(l[0])
print(l[-1])
print(l[-2])

# example for append
l=["hello","yourName","python"]
l.append(" for arya Mains")
print(l)
print(l[0])
print(l[-1])


#example for insert
l=[True,False,10,20]
l.insert(1,100)
print(l)


#question
l=[10,20,30,{"name":"dheeraj","address":["jaipur","kukas","home town","friend house"]}]
for i in l[-1]["address"]:
  print(i)


# question
l=[10,20,30,[40,50,[60,70,80]]]
for i in range(len(l[3])-1):
  print(l[-1][i])
# Out:
# length of list is :  6
# [10, 20, 30, 40, 'hello', True]
# 10
# True
# hello
# ['hello', 'yourName', 'python', ' for arya Mains']
# hello
#  for arya Mains
# [True, 100, False, 10, 20]
# jaipur
# kukas
# home town
# friend house
# 40
# 50

# %%
# dictoniry in Python

d={"name ":"dheeraj","age":20,"roll":"IT011"}
print(d.keys())
print(d.values())
for i in d.keys():
  print(i," =",d[i])



#question
d={
  "Message": "Number of Post office(s) found: 5",
  "Status": "Success",
  "PostOffice": [
    {
      "Name": "Jagatpura",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Malviya Nagar (Jaipur)",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Malviya Nagar Sector 11,12",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Mrec Jaipur",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Saraswati Nagar",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    }
  ]
}

for j in d.keys():
  if j=="PostOffice" :
    for i in PostOffice:


    print(d[j],"\n")
# Out:
# dict_keys(['name ', 'age', 'roll'])
# dict_values(['dheeraj', 20, 'IT011'])
# name   = dheeraj
# age  = 20
# roll  = IT011
# Number of Post office(s) found: 5
#
# Success
#
# ...
