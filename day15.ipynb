# %%
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
