# %%
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
print(df)
df.loc[4,"roll no"]=None
print(df)
# print("------------Removal of null value (by Default row)---------------")
# print(df.dropna())
# # for column
# df.dropna(axis=1)
# # by by any values
# df.fillna(0)


# roll-> 200 |marks=100
# df["roll no"]=df["roll no"].fillna(200)
# df["marks"]=df["marks"].fillna(100)
# df

# fill with  nan -> mean values
mean=df["marks"].mean()
df["marks"]=df["marks"].fillna(mean)
df
# Out:
#        name  roll no  marks
# 0   dheeraj      123    NaN
# 1     kunal     1234   20.0
# 2  abhishek    12345   30.0
# 3   praveen    12356   40.0
# 4    anjali  1234567   50.0
#        name  roll no  marks
# 0   dheeraj    123.0    NaN
# 1     kunal   1234.0   20.0
# 2  abhishek  12345.0   30.0
# 3   praveen  12356.0   40.0
# 4    anjali      NaN   50.0
#        name  roll no  marks
# 0   dheeraj    123.0   35.0
# 1     kunal   1234.0   20.0
# 2  abhishek  12345.0   30.0
# 3   praveen  12356.0   40.0
# 4    anjali      NaN   50.0

# %% [markdown]
# **Aggregation**

# %%
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
#manually
print(df["marks"].sum())
print(df["marks"].max())
print((df["marks"].min()))
print(df["marks"].mean())
# Using aggregation
print(df["marks"].agg(["sum","mean","max","min"]))
# Out:
# 140.0
# 50.0
# 20.0
# 35.0
# sum     140.0
# mean     35.0
# max      50.0
# min      20.0
# Name: marks, dtype: float64

# %% [markdown]
# **Concat of data frame**

# %%
import pandas as pd
url="https://raw.githubusercontent.com/student-dheerajyadav/DataScience__45days/main/file2.json"
df=pd.read_json(url)
df1=pd.read_json(url)
#concatination(by default row)
pd.concat([df,df1])
#concatination(by column)
df2=pd.concat([df,df1],axis=1)

# name(2)->change name inplace of abhishek
df2.loc[2,"name"]="nikita"
print(df2)
# Out:
#       name  roll no  marks     name  roll no  marks
# 0  dheeraj      123    NaN  dheeraj      123    NaN
# 1    kunal     1234   20.0    kunal     1234   20.0
# 2   nikita    12345   30.0   nikita    12345   30.0
# 3  praveen    12356   40.0  praveen    12356   40.0
# 4   anjali  1234567   50.0   anjali  1234567   50.0

# %% [markdown]
# **Matplotlib**

# %%
import matplotlib.pyplot as plt
score=[10,20,30,40]
over=[1,2,3,4]
plt.plot(score,over)
plt.show()
